# %%
import math
import cv2

# %%
#some observations made by manually running some experiment on my laptop webcam
#all the dimensions are in inch
#actual width of the object
WIDTH = 57
# Perpendicular distance from the camera
DISTANCE = 38
#pixels covered by the object in the image
PIXELS = 480
# focus of the camera
# this value will be used in future calculations
FOCUS = PIXELS * DISTANCE / WIDTH
FOCUS
# Out:
# 320.0

# %%
import numpy as np

# %%
import copy

# %%
Face = (9,8)
faces = []

# %%
# cap= cv2.VideoCapture('http://192.168.43.74:8080/video')
cap=cv2.VideoCapture(0)

# %%
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('a.avi', fourcc, 5.0, (640, 480))

# %%
face_model=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
body_model=cv2.CascadeClassifier('haarcascade_fullbody.xml')

# %%
status,photo=cap.read()

# %%
photo.shape
# Out:
# (480, 640, 3)

# %%
while True:
    status,photo=cap.read()
    photo=cv2.resize(photo,(640,480))
    face_cor=face_model.detectMultiScale(photo)
    faces=[]
    if len(face_cor)==0:
        pass
    else:
        for x in range(0,len(face_cor)):
            x1=face_cor[x][0]
            y1=face_cor[x][1]
            x2=x1+face_cor[x][2]
            y2=y1+face_cor[x][3]
            photo=cv2.rectangle(photo,(x1,y1),(x2,y2),[0,255,0])
        for face in face_cor:
            y = round((Face[0]*FOCUS/(face[2])),5)
            if face[0]   < 240:
                P = 480 - 2*(face[0] )
                P_ = y * P /38
                x = round((P_ * y / (FOCUS * 2)),5)
                x = -x
            elif face[0]   > 240:
                P = 2*(face[0] ) - 480
                P_ = y * P /38
                x = round((P_ *y / (FOCUS * 2)),5)
            else:
                x = 0
            faces.append((x,y))
        print(faces)
        warning = []
        for face in faces:
            warning.append([])
        if len(faces)>1:
            for a in range(len(faces)):
                for b in range(a + 1,len(faces)):
                    dist = (faces[a][0] - faces[b][0])**2 + ( faces[a][1] - faces[b][1])**2
                    dist = round(math.sqrt(dist),5)
                    if dist < 40:
                        warning[a].append(b)
                        warning[b].append(a)
                        cv2.putText(photo,"distance is "+str(dist-8),(50,50),cv2.FONT_HERSHEY_SIMPLEX,1,[0,0,255],2)
#                             pass
    print(warning)
    for war in range(len(warning)):
        if len(warning[war])>0:
            x1=face_cor[war][0]
            y1=face_cor[war][1]
            x2=x1+face_cor[war][2]
            y2=y1+face_cor[war][3]
            photo=cv2.rectangle(photo,(x1,y1),(x2,y2),[0,0,255])
    str1 = ''
    n = 0
    if len(warning)>0:
        for war in range(len(warning)):
#             n = n+1
            str1 += '\n'
            str1 += 'Person '
            war3 = str(n)
            str1 += war3
            str1 += ' near to : '
            for war2 in warning[war]:
                str1 += str(war2)
                str1 += ' , '
            n = n+1
    y0, dy = 50, 20
    for i, line in enumerate(str1.split('\n')):
        y1 = y0 + i*dy
        y1 = int(y1)
        cv2.putText(photo, line , (0,y1) ,cv2.FONT_HERSHEY_SIMPLEX,0.5,[0,0,255],2)
#         cv2.putText(photo, str1 , (50,200) ,cv2.FONT_HERSHEY_SIMPLEX,1,[0,0,255],3)
    
    out.write(photo)
    cv2.imshow('hi',photo)
    if cv2.waitKey(10)==13:
        break
cv2.destroyAllWindows()
# Out:
# [(0.15909000000000001, 11.755100000000001)]
# [[]]
# [(0.089440000000000006, 11.65992), (-16.53022, 35.55556)]
# [[1], [0]]
# [(-13.642110000000001, 32.0), (0.10838, 12.10084)]
# [[1], [0]]
# [(-15.19985, 33.882350000000002), (0.074109999999999995, 12.255319999999999)]
]
# [[1], [0]]
# [(-11.8093, 37.894739999999999), (8.6798199999999994, 27.961169999999999)]
# [[1], [0]]
# [(7.8312200000000001, 27.169809999999998), (-11.8093, 37.894739999999999)]
# [[1], [0]]
# [(7.0042, 26.42202), (-11.8093, 37.894739999999999)]
# [[1], [0]]
# [(6.1965899999999996, 25.486730000000001), (-11.69121, 37.894739999999999), (214.89795000000001, 102.85714)]
# [[1], [0], []]
# [(5.3886500000000002, 24.406780000000001), (-12.005050000000001, 38.399999999999999)]
# [[1], [0]]
# [(-11.8093, 37.894739999999999), (5.0315799999999999, 23.801649999999999)]
# [[1], [0]]
# [(4.9036099999999996, 23.606560000000002), (-11.8093, 37.894739999999999)]
# [[1], [0]]
# [(-11.8093, 37.894739999999999), (4.5972099999999996, 22.857140000000001)]
# [[1], [0]]
# [(-12.12632, 38.399999999999999), (4.3324699999999998, 21.984729999999999)]
# [[1], [0]]
# [(-12.12632, 38.399999999999999), (3.8128099999999998, 20.71942)]
# [[1], [0]]
# [(-11.8093, 37.894739999999999), (4.0141999999999998, 20.425529999999998)]
# [[1], [0]]
# [(-11.9274, 37.894739999999999), (3.6561699999999999, 19.328859999999999)]
# [[1], [0]]
# [(-12.247579999999999, 38.399999999999999), (3.6313599999999999, 18.947369999999999)]
# [[1], [0]]
# [(-12.247579999999999, 38.399999999999999), (3.3334700000000002, 18.22785)]
# [[1], [0]]
# [(-12.247579999999999, 38.399999999999999), (3.3039499999999999, 18.0)]
# [[1], [0]]
# [(-12.368840000000001, 38.399999999999999), (3.2228699999999999, 17.77778)]
# [[1], [0]]
# [(-12.045489999999999, 37.894739999999999), (3.3008500000000001, 17.77778)]
# [[1], [0]]
# [(-12.16358, 37.894739999999999), (3.1189300000000002, 17.349399999999999)]
# [[1], [0]]
# [(-12.16358, 37.894739999999999), (3.0451100000000002, 17.142859999999999)]
# [[1], [0]]
# [(-12.368840000000001, 38.399999999999999), (3.2861400000000001, 17.668710000000001)]
# [[1], [0]]
# [(-12.368840000000001, 38.399999999999999), (3.3268399999999998, 17.77778)]
# [[1], [0]]

# %%
len(face_cor)

# %%
dist

# %%
cap.release()
out.release()

# %%
# cv2.imwrite('a1.jpg',pic[0])
# cv2.imwrite('a2.jpg',pic[1])

# %%
# gauss = cv2.GaussianBlur(photo, (7,7), 0)
# # Apply Unsharp masking
# unsharp_image = cv2.addWeighted(photo, 2, gauss, -1, 0)

# %%
# photo.shape[0]

# %%
# import numpy as np
# import cv2

# cap = cv2.VideoCapture(0)

# # Define the codec and create VideoWriter object
# #fourcc = cv2.cv.CV_FOURCC(*'DIVX')
# #out = cv2.VideoWriter('output.avi',fourcc, 20.0, (640,480))
# out = cv2.VideoWriter('output.avi', -1, 20.0, (640,480))

# while(cap.isOpened()):
#     ret, frame = cap.read()
#     if ret==True:
#         frame = cv2.flip(frame,0)

#         # write the flipped frame
#         out.write(frame)

#         cv2.imshow('frame',frame)
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
#     else:
#         break

# # Release everything if job is finished
# cv2.destroyAllWindows()

# %%
# cap.release()
# out.release()

# %%
# import smtplib

# sender_email = "narayanhari1997@gmail.com"
# rec_email = "narayanharimittal@gmail.com"
# password = ''
# message = "Hey, this was sent using python"

# server = smtplib.SMTP('smtp.gmail.com', 587)
# server.starttls()
# server.login(sender_email, password)
# print("Login success")
# server.sendmail(sender_email, rec_email, message)
# print("Email has been sent to ", rec_email)
