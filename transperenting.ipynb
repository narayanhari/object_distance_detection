# %%
import math
import cv2

# %%
#some observations made by manually running some experiment on my laptop webcam
#all the dimensions are in inch
#actual width of the object
WIDTH = 57
# Perpendicular distance from the camera
DISTANCE = 38
#pixels covered by the object in the image
PIXELS = 480
# focus of the camera
# this value will be used in future calculations
FOCUS = PIXELS * DISTANCE / WIDTH
FOCUS
# Out:
# 320.0

# %%
import numpy as np

# %%
import copy

# %%
Face = (9,8)
faces = []

# %%
# cap= cv2.VideoCapture('http://192.168.43.74:8080/video')
cap=cv2.VideoCapture(0)

# %%
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('a.avi', fourcc, 5.0, (640, 480))

# %%
face_model=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
body_model=cv2.CascadeClassifier('haarcascade_fullbody.xml')

# %%
status,photo=cap.read()

# %%
photo.shape
# Out:
# (480, 640, 3)

# %%
while True:
    status,photo=cap.read()
    photo=cv2.resize(photo,(640,480))
    face_cor=face_model.detectMultiScale(photo)
    faces=[]
    if len(face_cor)==0:
        pass
    else:
        for x in range(0,len(face_cor)):
            x1=face_cor[x][0]
            y1=face_cor[x][1]
            x2=x1+face_cor[x][2]
            y2=y1+face_cor[x][3]
            photo=cv2.rectangle(photo,(x1,y1),(x2,y2),[0,255.0])
        for face in face_cor:
            y = round((Face[0]*FOCUS/(face[2])),5)
            if face[0]   < 240:
                P = 480 - 2*(face[0] )
                P_ = y * P /38
                x = round((P_ * y / (FOCUS * 2)),5)
                x = -x
            elif face[0]   > 240:
                P = 2*(face[0] ) - 480
                P_ = y * P /38
                x = round((P_ *y / (FOCUS * 2)),5)
            else:
                x = 0
            faces.append((x,y))
        print(faces)
        warning = []
        for face in faces:
            warning.append([])
        if len(faces)>1:
            for a in range(len(faces)):
                for b in range(a + 1,len(faces)):
                    dist = (faces[a][0] - faces[b][0])**2 + ( faces[a][1] - faces[b][1])**2
                    dist = round(math.sqrt(dist),5)
                    if dist < 70:
                        warning[a].append(b)
                        warning[b].append(a)
                        cv2.putText(photo,"distance is "+str(dist-8),(50,50),cv2.FONT_HERSHEY_SIMPLEX,1,[0,0,255],2)
#                             pass
    print(warning)
    str1 = ''
    n = 0
    if len(warning)>1:
        for war in range(len(warning)):
#             n = n+1
            str1 += '\n'
            str1 += 'Person '
            war3 = str(n)
            str1 += war3
            str1 += ' near to : '
            for war2 in warning[war]:
                str1 += str(war2)
                str1 += ' , '
                n = n+1
    y0, dy = 50, 20
    for i, line in enumerate(str1.split('\n')):
        y1 = y0 + i*dy
        y1 = int(y1)
        cv2.putText(photo, line , (0,y1) ,cv2.FONT_HERSHEY_SIMPLEX,0.5,[0,0,255],2)
#         cv2.putText(photo, str1 , (50,200) ,cv2.FONT_HERSHEY_SIMPLEX,1,[0,0,255],3)
    
    out.write(photo)
    cv2.imshow('hi',photo)
    if cv2.waitKey(10)==13:
        break
cv2.destroyAllWindows()
# Out:
# [(-0.31304999999999999, 11.65992), (-16.30658, 36.0)]
# [[1], [0]]
# [(-0.47260999999999997, 11.428570000000001), (-16.722020000000001, 36.4557)]
# [[1], [0]]
# [(-0.45462000000000002, 11.33858), (-16.612729999999999, 36.4557)]
# [[1], [0]]
# [(-0.46555999999999997, 11.4741), (-16.503430000000002, 36.4557)]
# [[1], [0]]
# [
(-16.503430000000002, 36.4557)]
# [[1], [0]]
# [(4.68947, 72.0), (-17.041419999999999, 36.923079999999999)]
# [[1], [0]]
# [(6.3947399999999996, 72.0), (-16.612729999999999, 36.4557)]
# [[1], [0]]
# [(10.763, 73.846149999999994), (-16.30658, 36.0)]
# [[1], [0]]
# [(15.773680000000001, 72.0), (-16.413160000000001, 36.0)]
# [[1], [0]]
# [(21.526, 73.846149999999994), (-16.114360000000001, 35.55556)]
# [[1], [0]]
# [(23.021049999999999, 72.0), (-16.413160000000001, 36.0)]
# [[1], [0]]
# [(-16.413160000000001, 36.0), (26.43158, 72.0)]
# [[1], [0]]
# [(26.857890000000001, 72.0), (-16.94061, 36.4557)]
# [[1], [0]]
# [(27.80442, 73.846149999999994), (-16.519739999999999, 36.0)]
# [[1], [0]]
# [(26.00526, 72.0), (-16.62632, 36.0)]
# [[1], [0]]
# [(27.710529999999999, 72.0), (-16.62632, 36.0)]
# [[1], [0]]
# [(28.989470000000001, 72.0), (-17.049900000000001, 36.4557)]
# [[1], [0]]
# [(35.42821, 73.846149999999994), (-17.049900000000001, 36.4557)]
# [[1], [0]]
# [(36.236840000000001, 72.0), (-17.049900000000001, 36.4557)]
# [[1], [0]]
# [(42.603549999999998, 73.846149999999994), (-16.62632, 36.0)]
# [[], []]
# [(43.910530000000001, 72.0), (-16.94061, 36.4557)]
# [[], []]
# [(47.985050000000001, 73.846149999999994), (-16.62632, 36.0)]
# [[], []]
# [(44.635080000000002, 70.243899999999996), (-16.62632, 36.0)]
# [[], []]
# [(-16.218330000000002, 35.55556), (46.894739999999999, 72.0)]
# [[], []]
# [(49.778880000000001, 73.846149999999994), (-15.82517, 35.121949999999998)]
# [[], []]
# [(54.79515, 75.789469999999994), (-16.114360000000001, 35.55556)]
# [[], []]
# [(52.863160000000001, 72.0), (-16.114360000000001, 35.55556)]
# [[], []]
# [(58.748049999999999, 73.846149999999994), (-16.010400000000001, 35.55556)]
# [[], []]
# [(59.257890000000003, 72.0), (-16.010400000000001, 35.55556)]
# [[], []]
# [(54.522019999999998, 68.571430000000007), (-16.413160000000001, 36.0)]
# [[], []]
# [(-16.413160000000001, 36.0), (60.963160000000002, 72.0)]
# [[], []]
# [(57.214060000000003, 70.243899999999996), (-16.30658, 36.0)]
# [[], []]
# [(57.214060000000003, 70.243899999999996), (-16.30658, 36.0)]
# [[], []]
# [(54.373649999999998, 70.243899999999996), (-16.30658, 36.0)]
# [[], []]
# [(49.495170000000002, 68.571430000000007), (-16.30658, 36.0)]
# [[], []]
# [(48.721809999999998, 68.571430000000007), (-16.010400000000001, 35.55556)]
# [[], []]
# [(42.778950000000002, 64.0), (-16.199999999999999, 36.0)]
# [[1], [0]]
# [(40.75958, 61.276600000000002), (-16.503430000000002, 36.4557)]
# [[1], [0]]
# [(38.352440000000001, 58.775509999999997), (-16.093419999999998, 36.0)]
# [[1], [0]]
# [(37.106529999999999, 57.600000000000001), (-16.199999999999999, 36.0)]
# [[1], [0]]
# [(33.5503, 55.384619999999998), (-17.041419999999999, 36.923079999999999)]
# [[1], [0]]
# [(29.941520000000001, 53.333329999999997), (-16.199999999999999, 36.0)]
# [[1], [0]]
# [(28.070170000000001, 53.333329999999997), (-16.722020000000001, 36.4557)]
# [[1], [0]]
# [(25.01343, 51.428570000000001), (-16.30658, 36.0)]
# [[1], [0]]
# [(24.578410000000002, 51.428570000000001), (-16.30658, 36.0)]
# [[1], [0]]
# [(22.53436, 48.813560000000003), (-16.010400000000001, 35.55556)]
# [[1], [0]]
# [(22.92632, 48.0), (-16.199999999999999, 36.0)]
# [[1], [0]]
# [(22.890630000000002, 46.451610000000002), (-16.199999999999999, 36.0)]
# [[1], [0]]
# [(20.983029999999999, 43.636360000000003), (-16.093419999999998, 36.0)]
# [[1], [0]]
# [(19.341360000000002, 41.739130000000003), (-16.612729999999999, 36.4557)]
# [[1], [0]]
# [(17.5, 40.0), (-16.612729999999999, 36.4557)]
# [[1], [0]]
# [(14.76163, 37.894739999999999), (-16.722020000000001, 36.4557)]
# [[1], [0]]
# [(12.68289, 36.0), (-16.114360000000001, 35.55556)]
# [[1], [0]]
# [(-16.831309999999998, 36.4557), (10.51379, 33.488370000000003)]
# [[1], [0]]
# [(-16.519739999999999, 36.0), (9.8169400000000007, 32.359549999999999)]
# [[1], [0]]
# [(-16.94061, 36.4557), (8.8775600000000008, 30.638300000000001)]
# [[1], [0]]
# [(-16.218330000000002, 35.55556), (8.4819099999999992, 29.690719999999999)]
# [[1], [0]]
# [(7.8439899999999998, 27.961169999999999), (-16.94061, 36.4557)]
# [[1], [0]]
# [(7.6490999999999998, 27.169809999999998), (-16.519739999999999, 36.0)]
# [[1], [0]]
# [(7.2156599999999997, 26.181819999999998), (-16.62632, 36.0)]
# [[1], [0]]
# [(5.9246499999999997, 24.20168), (-16.94061, 36.4557)]
# [[1], [0]]
# [(4.7583700000000002, 23.039999999999999), (-16.62632, 36.0)]
# [[1], [0]]
# [(4.0989399999999998, 22.325579999999999), (-16.62632, 36.0)]
# [[1], [0]]
# [(2.6863000000000001, 20.86957), (-16.519739999999999, 36.0)]
# [[1], [0]]
# [(-16.519739999999999, 36.0), (1.9078900000000001, 20.0)]
# [[1], [0]]
# [(-16.218330000000002, 35.55556), (1.36951, 18.823530000000002), (33.30592, 90.0)]
# [[1], [0], []]
# [(1.1749099999999999, 18.22785), (-16.732890000000001, 36.0)]
# [[1], [0]]
# [(1.1457200000000001, 18.0), (-16.732890000000001, 36.0)]
# [[1], [0]]
# [(0.99014000000000002, 17.349399999999999), (-16.732890000000001, 36.0)]
# [[1], [0]]
# [(1.0525899999999999, 17.888200000000001), (-16.42625, 35.55556)]
# [[1], [0]]
# [(1.23326, 18.461539999999999), (-16.42625, 35.55556)]
# [[1], [0]]
# [(0.95386000000000004, 17.245509999999999), (-17.159199999999998, 36.4557)]
# [[1], [0]]
# [(28.95467, 82.285709999999995), (1.0905199999999999, 17.560980000000001), (-16.53022, 35.55556)]
# [[2], [2], [0, 1]]
# [(1.0891500000000001, 17.349399999999999), (-17.26849, 36.4557)]
# [[1], [0]]
# [(1.1274500000000001, 17.454550000000001), (-16.839469999999999, 36.0)]
# [[1], [0]]
# [(1.1634100000000001, 17.349399999999999), (-16.839469999999999, 36.0)]
# [[1], [0]]
# [(1.24268, 17.560980000000001), (-17.159199999999998, 36.4557)]
# [[1], [0]]
# [(1.21732, 17.560980000000001), (-17.26849, 36.4557)]
# [[1], [0]]
# [(1.1495200000000001, 17.245509999999999), (-17.159199999999998, 36.4557)]
# [[1], [0]]
# [(1.13588, 17.142859999999999), (-17.26849, 36.4557)]
# [[1], [0]]
# [(1.11171, 17.142859999999999), (-16.53022, 35.55556)]
# [[1], [0]]
# [(1.27355, 17.77778), (-17.26849, 36.4557)]
# [[1], [0]]
# [(1.27355, 17.77778), (-17.26849, 36.4557)]
# [[1], [0]]
# [(1.3322400000000001, 18.0), (-17.26849, 36.4557)]
# [[1], [0]]
# [(1.21732, 17.560980000000001), (-16.839469999999999, 36.0)]
# [[1], [0]]
# [(1.30559, 18.0), (-17.159199999999998, 36.4557)]
# [[1], [0]]

# %%
len(face_cor)

# %%
dist

# %%
cap.release()
out.release()

# %%
# cv2.imwrite('a1.jpg',pic[0])
# cv2.imwrite('a2.jpg',pic[1])

# %%
# gauss = cv2.GaussianBlur(photo, (7,7), 0)
# # Apply Unsharp masking
# unsharp_image = cv2.addWeighted(photo, 2, gauss, -1, 0)

# %%
# photo.shape[0]

# %%
# import numpy as np
# import cv2

# cap = cv2.VideoCapture(0)

# # Define the codec and create VideoWriter object
# #fourcc = cv2.cv.CV_FOURCC(*'DIVX')
# #out = cv2.VideoWriter('output.avi',fourcc, 20.0, (640,480))
# out = cv2.VideoWriter('output.avi', -1, 20.0, (640,480))

# while(cap.isOpened()):
#     ret, frame = cap.read()
#     if ret==True:
#         frame = cv2.flip(frame,0)

#         # write the flipped frame
#         out.write(frame)

#         cv2.imshow('frame',frame)
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
#     else:
#         break

# # Release everything if job is finished
# cv2.destroyAllWindows()

# %%
# cap.release()
# out.release()

# %%
# import smtplib

# sender_email = "narayanhari1997@gmail.com"
# rec_email = "narayanharimittal@gmail.com"
# password = ''
# message = "Hey, this was sent using python"

# server = smtplib.SMTP('smtp.gmail.com', 587)
# server.starttls()
# server.login(sender_email, password)
# print("Login success")
# server.sendmail(sender_email, rec_email, message)
# print("Email has been sent to ", rec_email)
