# %%
import math
import cv2

# %%
#some observations made by manually running some experiment on my laptop webcam
#all the dimensions are in inch
#actual width of the object
WIDTH = 57
# Perpendicular distance from the camera
DISTANCE = 38
#pixels covered by the object in the image
PIXELS = 480
# focus of the camera
# this value will be used in future calculations
FOCUS = PIXELS * DISTANCE / WIDTH
FOCUS
# Out:
# 320.0

# %%
import numpy as np

# %%
import copy

# %%
Face = (9,8)
faces = []

# %%
# cap= cv2.VideoCapture('http://192.168.43.74:8080/video')
cap=cv2.VideoCapture(0)

# %%
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('a.avi', fourcc, 5.0, (640, 480))

# %%
face_model=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
body_model=cv2.CascadeClassifier('haarcascade_fullbody.xml')

# %%
status,photo=cap.read()

# %%
photo.shape
# Out:
# (480, 640, 3)

# %%
while True:
    status,photo=cap.read()
    photo=cv2.resize(photo,(640,480))
    face_cor=face_model.detectMultiScale(photo)
    faces=[]
    if len(face_cor)==0:
        pass
    else:
        for x in range(0,len(face_cor)):
            x1=face_cor[x][0]
            y1=face_cor[x][1]
            x2=x1+face_cor[x][2]
            y2=y1+face_cor[x][3]
            photo=cv2.rectangle(photo,(x1,y1),(x2,y2),[0,255,0])
        for face in face_cor:
            y = round((Face[0]*FOCUS/(face[2])),5)
            if face[0]   < 240:
                P = 480 - 2*(face[0] )
                P_ = y * P /38
                x = round((P_ * y / (FOCUS * 2)),5)
                x = -x
            elif face[0]   > 240:
                P = 2*(face[0] ) - 480
                P_ = y * P /38
                x = round((P_ *y / (FOCUS * 2)),5)
            else:
                x = 0
            faces.append((x,y))
        print(faces)
        warning = []
        for face in faces:
            warning.append([])
        if len(faces)>1:
            for a in range(len(faces)):
                for b in range(a + 1,len(faces)):
                    dist = (faces[a][0] - faces[b][0])**2 + ( faces[a][1] - faces[b][1])**2
                    dist = round(math.sqrt(dist),5)
                    if dist < 40:
                        warning[a].append(b)
                        warning[b].append(a)
                        cv2.putText(photo,"distance is "+str(dist-8),(50,50),cv2.FONT_HERSHEY_SIMPLEX,1,[0,0,255],2)
#                             pass
    print(warning)
    for war in range(len(warning)):
        if len(warning[war])>0:
            x1=face_cor[war][0]
            y1=face_cor[war][1]
            x2=x1+face_cor[war][2]
            y2=y1+face_cor[war][3]
            photo=cv2.rectangle(photo,(x1,y1),(x2,y2),[0,0,255])
    str1 = ''
    n = 0
    if len(warning)>0:
        for war in range(len(warning)):
#             n = n+1
            str1 += '\n'
            str1 += 'Person '
            war3 = str(n)
            str1 += war3
            str1 += ' near to : '
            for war2 in warning[war]:
                str1 += str(war2)
                str1 += ' , '
            n = n+1
    y0, dy = 50, 20
    for i, line in enumerate(str1.split('\n')):
        y1 = y0 + i*dy
        y1 = int(y1)
        cv2.putText(photo, line , (0,y1) ,cv2.FONT_HERSHEY_SIMPLEX,0.5,[0,0,255],2)
#         cv2.putText(photo, str1 , (50,200) ,cv2.FONT_HERSHEY_SIMPLEX,1,[0,0,255],3)
    
    out.write(photo)
    cv2.imshow('hi',photo)
    if cv2.waitKey(10)==13:
        break
cv2.destroyAllWindows()
# Out:
# [(0.11362, 14.048780000000001)]
# [[]]
# [(0.13507, 14.32836)]
# [[]]
# [(0.11473, 14.117649999999999)]
# [[]]
# [(0.11473, 14.117649999999999)]
# [[]]
# [(0.14896999999999999, 14.187189999999999)]
# [[]]
# [(0.16389999999999999, 14.117649999999999)]
# [[]]
# [(0.13111999999999999, 14.117649999999999)]
# [[]]
# [(0.18572, 14.32836)]
# [[]]
# [(0.16552, 14.187189999999999)]
# [[]]
# [(0.16883000000000001, 14.32836)]
# [[]]
# [(0.16717000000000001, 14.257429999999999)]
# [[]]
# [(0.20669000000000001, 14.47236)]
# [[]]
# [(0.18207999999999999, 14.187189999999999)]
# [[]]
# [(0.18207999999999999, 14.187189999999999)]
# [[]]
# [(0.16231000000000001, 14.048780000000001)]
# [[]]
# [(0.10827000000000001, 13.71429)]
# [[]]
# [(0.11143, 13.913040000000001)]
# [[]]
# [(0.10931, 13.7799)]
# [[]]
# [(0.093689999999999996, 13.7799)]
# [[]]
# [(0.16552, 14.187189999999999)]
# [[]]
# [(0.11252, 13.98058)]
# [[]]
# [(0.094600000000000004, 13.84615)]
# [[]]
# [(0.11473, 14.117649999999999)]
# [[]]
# [(0.11817999999999999, 14.32836)]
# [[]]
# [(0.11937, 14.4)]
# [[]]
# [(0.08276, 14.187189999999999)]
# [[]]
# [(0.067530000000000007, 14.32836)]
# [[]]
# [(-0.016070000000000001, 13.98058)]
# [[]]
# [(0, 14.048780000000001)]
# [[]]
# [(-0.052200000000000003, 14.545450000000001)]
# [[]]
# [(-0.23874000000000001, 14.4)]
# [[]]
# [(-0.52966999999999997, 14.187189999999999)]
# [[]]
# [(-1.02989, 14.32836)]
# [[]]
# [(-1.6535500000000001, 14.47236)]
# [[]]
# [(-1.9420900000000001, 13.913040000000001)]
# [[]]
# [(-2.27643, 13.03167)]
# [[]]
# [(-2.5884200000000002, 13.150679999999999)]
# [[]]
# [(-2.2828300000000001, 13.649290000000001)]
# [[]]
# [(-2.0253100000000002, 12.68722)]
# [[]]
# [(-1.5607200000000001, 11.900829999999999)]
# [[]]
# [(-1.61182, 11.707319999999999)]
# [[]]
# [(-2.0029699999999999, 11.4741)]
# [[]]
# [(-2.0952999999999999, 12.10084)]
# [[]]
# [(-1.70875, 12.360519999999999)]
# [[]]
# [(-1.66926, 12.307689999999999)]
# [[]]
# [(-1.3179799999999999, 12.413790000000001)]
# [[]]
# [(-1.41977, 12.360519999999999)]
# [[]]
# [(-1.7039299999999999, 12.576420000000001)]
# [[]]
# [(-2.0640399999999999, 13.584910000000001)]
# [[]]
# [(-2.1683599999999998, 14.187189999999999)]
# [[]]
# [(-2.2047300000000001, 14.47236)]
# [[]]
# [(-2.2759, 15.0)]
# [[]]
# [(-2.47132, 15.56757)]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
#
# [[], []]
# [(73.444999999999993, 70.243899999999996), (-1.2156, 42.98507)]
# [[], []]
# [(63.066560000000003, 65.454549999999998), (0, 41.142859999999999)]
# [[1], [0]]
# [(66.895809999999997, 68.571430000000007), (0.40593000000000001, 40.563380000000002)]
# [[], []]
# [(0.51198999999999995, 39.45205)]
# [[]]
# [(0.34514, 37.4026)]
# [[]]
# [(0.42631999999999998, 36.0)]
# [[]]
# [(0.49507000000000001, 34.698799999999999)]
# [[]]
# [(0.87002999999999997, 34.285710000000002)]
# [[]]
# [(1.1329100000000001, 33.882350000000002)]
# [[]]
# [(1.09474, 32.0)]
# [[]]
# [(1.2631600000000001, 32.0)]
# [[]]
# [(1.05698, 32.727269999999997)]
# [[]]
# [(-0.94725000000000004, 32.359549999999999)]
# [[]]
# [(-4.7564200000000003, 32.727269999999997)]
# [[]]
# [(-8.4017300000000006, 31.648350000000001)]
# [[]]
# [(-9.2631599999999992, 32.0)]
# [[]]
# [(-7.4947800000000004, 31.304349999999999)]
# [[]]
# [(-3.6221800000000002, 29.38776)]
# [[]]
# [(-0.34447, 26.42202)]
# [[]]
# [(0.52105000000000001, 24.0)]
# [[]]
# [(0.079490000000000005, 21.984729999999999)]
# [[]]
# [(-0.32895000000000002, 20.0)]
# [[]]
# [(-0.46052999999999999, 20.0)]
# [[]]
# [(-0.20044000000000001, 17.454550000000001)]
# [[]]
# [(0.69006999999999996, 15.48387)]
# [[]]
# [(1.20269, 15.48387)]
# [[]]
# [(1.0470600000000001, 15.078530000000001)]
# [[]]
# [(0.55803999999999998, 15.56757)]
# [[]]
# [(0.45308999999999999, 14.845359999999999)]
# [[]]

# %%
len(face_cor)

# %%
dist

# %%
cap.release()
out.release()

# %%
# cv2.imwrite('a1.jpg',pic[0])
# cv2.imwrite('a2.jpg',pic[1])

# %%
# gauss = cv2.GaussianBlur(photo, (7,7), 0)
# # Apply Unsharp masking
# unsharp_image = cv2.addWeighted(photo, 2, gauss, -1, 0)

# %%
# photo.shape[0]

# %%
# import numpy as np
# import cv2

# cap = cv2.VideoCapture(0)

# # Define the codec and create VideoWriter object
# #fourcc = cv2.cv.CV_FOURCC(*'DIVX')
# #out = cv2.VideoWriter('output.avi',fourcc, 20.0, (640,480))
# out = cv2.VideoWriter('output.avi', -1, 20.0, (640,480))

# while(cap.isOpened()):
#     ret, frame = cap.read()
#     if ret==True:
#         frame = cv2.flip(frame,0)

#         # write the flipped frame
#         out.write(frame)

#         cv2.imshow('frame',frame)
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
#     else:
#         break

# # Release everything if job is finished
# cv2.destroyAllWindows()

# %%
# cap.release()
# out.release()

# %%
# import smtplib

# sender_email = "narayanhari1997@gmail.com"
# rec_email = "narayanharimittal@gmail.com"
# password = ''
# message = "Hey, this was sent using python"

# server = smtplib.SMTP('smtp.gmail.com', 587)
# server.starttls()
# server.login(sender_email, password)
# print("Login success")
# server.sendmail(sender_email, rec_email, message)
# print("Email has been sent to ", rec_email)
