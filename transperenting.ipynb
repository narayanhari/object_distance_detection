# %%
import math
import cv2

# %%
#some observations made by manually running some experiment on my laptop webcam
#all the dimensions are in inch
#actual width of the object
WIDTH = 57
# Perpendicular distance from the camera
DISTANCE = 38
#pixels covered by the object in the image
PIXELS = 480
# focus of the camera
# this value will be used in future calculations
FOCUS = PIXELS * DISTANCE / WIDTH
FOCUS
# Out:
# 320.0

# %%
import numpy as np

# %%
import copy

# %%
Face = (9,8)
faces = []

# %%
# cap= cv2.VideoCapture('http://192.168.43.74:8080/video')
cap=cv2.VideoCapture(0)

# %%
face_model=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
body_model=cv2.CascadeClassifier('haarcascade_fullbody.xml')

# %%
status,photo=cap.read()

# %%
photo.shape
# Out:
# (480, 640, 3)

# %%
while True:
    status,photo=cap.read()
    photo=cv2.resize(photo,(640,480))
    face_cor=face_model.detectMultiScale(photo)
    faces=[]
    if len(face_cor)==0:
        pass
    else:
        for x in range(0,len(face_cor)):
            x1=face_cor[x][0]
            y1=face_cor[x][1]
            x2=x1+face_cor[x][2]
            y2=y1+face_cor[x][3]
            photo=cv2.rectangle(photo,(x1,y1),(x2,y2),[0,255.0])
        for face in face_cor:
            y = round((Face[0]*FOCUS/(face[2])),5)
            if face[0]   < 240:
                P = 480 - 2*(face[0] )
                P_ = y * P /38
                x = round((P_ * y / (FOCUS * 2)),5)
                x = -x
            elif face[0]   > 240:
                P = 2*(face[0] ) - 480
                P_ = y * P /38
                x = round((P_ *y / (FOCUS * 2)),5)
            else:
                x = 0
            faces.append((x,y))
        print(faces)
        warning = []
        for face in faces:
            warning.append([])
        if len(faces)>1:
            for a in range(len(faces)):
                for b in range(a + 1,len(faces)):
                    dist = (faces[a][0] - faces[b][0])**2 + ( faces[a][1] - faces[b][1])**2
                    dist = round(math.sqrt(dist),5)
                    if dist < 500:
                        warning[a].append(b)
                        warning[b].append(a)
                        cv2.putText(photo,str(dist),(50,50),cv2.FONT_HERSHEY_SIMPLEX,1,[0,0,255],3)
#                             pass
    print(warning)
    str1 = ''
    n = 0
    if len(warning)>1:
        for war in range(len(warning)):
#             n = n+1
            str1 += '\n'
            str1 += 'Person '
            war3 = str(n)
            str1 += war3
            str1 += ': '
            for war2 in warning[war]:
                str1 += str(war2)
                str1 += ' , '
                n = n+1
    y0, dy = 50, 20
    for i, line in enumerate(str1.split('\n')):
        y1 = y0 + i*dy
        y1 = int(y1)
        cv2.putText(photo, line , (0,y1) ,cv2.FONT_HERSHEY_SIMPLEX,0.5,[0,0,255],3)
#         cv2.putText(photo, str1 , (50,200) ,cv2.FONT_HERSHEY_SIMPLEX,1,[0,0,255],3)
    
    cv2.imshow('hi',photo)
    if cv2.waitKey(10)==13:
        break
cv2.destroyAllWindows()
# Out:
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [[]]
# [(0.73199999999999998, 13.21101)]
# [[]]
# [(0.66237999999999997, 13.090909999999999)]
# [[]]
# [(0.40415000000000001, 12.203390000000001)]
# [[]]
# [(0.41109000000000001, 12.307689999999999)]
# [[]]
# [(0.26789000000000002, 11.900829999999999)]
# [[]]
# [(0.22361, 11.65992)]
# [[]]
# [(0.20132, 12.0)]
# [[]]
# [(0.09017, 11.707319999999999)]
# [[]]
# [(0.078899999999999998, 11.707319999999999)]
]
# [(-2.5525699999999998, 16.647400000000001)]
# [[]]
# [(-2.5962499999999999, 16.941179999999999)]
# [[]]
# [(-2.5233099999999999, 16.55172)]
# [[]]
# [(-2.5893000000000002, 16.842110000000002)]
# [[]]
# [(-2.5525699999999998, 16.647400000000001), (5.8227099999999998, 21.654140000000002)]
# [[1], [0]]
# [(5.48766, 21.021899999999999), (-2.5592800000000002, 16.74419)]
# [[1], [0]]
# [(5.2150299999999996, 20.425529999999998), (-2.5592800000000002, 16.74419)]
# [[1], [0]]
# [(5.8760199999999996, 21.33333), (-2.5659700000000001, 16.842110000000002)]
# [[1], [0]]
# [(5.82681, 21.176469999999998), (-2.5893000000000002, 16.842110000000002)]
# [[1], [0]]
# [(5.4208800000000004, 20.425529999999998), (-2.5592800000000002, 16.74419)]
# [[1], [0]]
# [(5.6133100000000002, 20.71942), (-2.5525699999999998, 16.647400000000001)]
# [[1], [0]]
# [(5.4462900000000003, 20.281690000000001), (-2.5962499999999999, 16.941179999999999)]
# [[1], [0]]
# [(5.63781, 20.571429999999999), (-2.5893000000000002, 16.842110000000002)]
# [[1], [0]]
# [(5.5815999999999999, 20.281690000000001), (-2.5592800000000002, 16.74419)]
# [[1], [0]]
# [(5.5038099999999996, 20.139859999999999), (-2.5893000000000002, 16.842110000000002)]
# [[1], [0]]
# [(5.3618399999999999, 20.0), (-2.5962499999999999, 16.941179999999999)]
# [[1], [0]]
# [(5.3618399999999999, 20.0), (-2.6270600000000002, 17.041419999999999)]
# [[1], [0]]
# [(5.2881400000000003, 19.862069999999999), (-2.5659700000000001, 16.842110000000002)]
# [[1], [0]]
# [(5.4704499999999996, 20.139859999999999), (-2.5592800000000002, 16.74419)]
# [[1], [0]]
# [(5.3618399999999999, 20.0), (-2.5362200000000001, 16.74419)]
# [[1], [0]]
# [(5.4371, 20.139859999999999), (-2.5525699999999998, 16.647400000000001)]
# [[1], [0]]
# [(5.5139399999999998, 20.281690000000001), (-2.5297800000000001, 16.647400000000001)]
# [[1], [0]]
# [(5.7074100000000003, 20.571429999999999), (-2.5297800000000001, 16.647400000000001)]
# [[1], [0]]
# [(5.5924300000000002, 20.425529999999998), (-2.5592800000000002, 16.74419)]
# [[1], [0]]
# [(5.4801200000000003, 20.281690000000001), (-2.5233099999999999, 16.55172)]
# [[1], [0]]
# [(5.2232599999999998, 19.862069999999999), (-2.5007799999999998, 16.55172)]
# [[1], [0]]
# [(5.2960500000000001, 20.0), (-2.5458400000000001, 16.55172), (-2.8849900000000002, 17.77778)]
# [[1, 2], [0, 2], [0, 1]]
# [(5.0189599999999999, 19.591840000000001), (-2.5233099999999999, 16.55172)]
# [[1], [0]]
# [(5.0505300000000002, 19.591840000000001), (-2.5297800000000001, 16.647400000000001)]
# [[1], [0]]
# [(4.9202300000000001, 19.45946), (-2.4883099999999998, 16.36364)]
# [[1], [0]]
# [(5.0189599999999999, 19.591840000000001), (-2.5233099999999999, 16.55172)]
# [[1], [0]]
# [(5.0559500000000002, 19.726030000000002), (-2.5168300000000001, 16.457139999999999)]
# [[1], [0]]
# [(5.1199500000000002, 19.726030000000002), (-2.5233099999999999, 16.55172)]
# [[1], [0]]
# [(5.2631600000000001, 20.0), (-2.45424, 16.179780000000001)]
# [[1], [0]]
# [(5.63781, 20.571429999999999), (-2.5233099999999999, 16.55172), (-3.10623, 18.7013)]
# [[1, 2], [0, 2], [0, 1]]
# [(5.7665899999999999, 20.86957), (-2.5458400000000001, 16.55172)]
# [[1], [0]]
# [(5.6486099999999997, 20.71942), (-2.5683699999999998, 16.55172), (-3.0055900000000002, 18.22785)]
# [[1, 2], [0, 2], [0, 1]]
# [(6.2083199999999996, 21.654140000000002), (-2.5168300000000001, 16.457139999999999)]
# [[1], [0]]
# [(6.8510799999999996, 22.67717), (-2.5168300000000001, 16.457139999999999)]
# [[1], [0]]
# [(8.5668699999999998, 24.827590000000001), (-2.5525699999999998, 16.647400000000001)]
# [[1], [0]]
# [(8.8712400000000002, 25.043479999999999), (-2.5458400000000001, 16.55172)]
# [[1], [0]]
# [(-2.4820500000000001, 16.271190000000001), (10.316140000000001, 26.181819999999998)]
# [[1], [0]]
# [(-2.5069900000000001, 16.647400000000001), (12.86515, 27.692309999999999)]
# [[1], [0]]
# [(15.31101, 29.090910000000001), (-2.5297800000000001, 16.647400000000001)]
# [[1], [0]]
# [(-2.5007799999999998, 16.55172), (18.668140000000001, 30.31579)]
# [[1], [0]]
# [(19.539470000000001, 30.0), (-2.5362200000000001, 16.74419)]
# [[1], [0]]
# [(23.934940000000001, 31.304349999999999), (-2.5362200000000001, 16.74419)]
# [[1], [0]]
# [(-2.5233099999999999, 16.55172)]
# [[]]
# [(-2.5525699999999998, 16.647400000000001)]
# [[]]
# [(-2.4945599999999999, 16.457139999999999)]
# [[]]
# [(-2.4945599999999999, 16.457139999999999)]
# [[]]
# [(27.756430000000002, 33.103450000000002), (-2.5823399999999999, 16.74419)]
# [[1], [0]]
# [(22.870909999999999, 30.967739999999999), (-2.5297800000000001, 16.647400000000001)]
# [[1], [0]]
# [(18.160620000000002, 28.235289999999999), (-2.5233099999999999, 16.55172)]
# [[1], [0]]
# [(14.995039999999999, 26.181819999999998), (-2.6053899999999999, 16.74419)]
# [[1], [0]]
# [(14.301159999999999, 25.714289999999998), (-2.5592800000000002, 16.74419)]
# [[1], [0]]
# [(13.82263, 25.043479999999999), (-2.5962499999999999, 16.941179999999999)]
# [[1], [0]]
# [(17.483650000000001, 27.169809999999998), (-2.5362200000000001, 16.74419)]
# [[1], [0]]
# [(18.065729999999999, 27.428570000000001), (-2.5659700000000001, 16.842110000000002)]
# [[1], [0]]
# [(-2.5007799999999998, 16.55172)]
# [[]]
# [(-2.5726499999999999, 16.941179999999999)]
# [[]]
# [(-2.5726499999999999, 16.941179999999999)]
# [[]]
# [(-2.5659700000000001, 16.842110000000002)]
# [[]]
# [(-2.5726499999999999, 16.941179999999999), (98.660399999999996, 92.903229999999994)]
# [[1], [0]]
# [(-2.60318, 17.041419999999999), (85.843180000000004, 68.571430000000007)]
# [[1], [0]]
# [(-2.5007799999999998, 16.55172)]
# [[]]
# [(-2.5069900000000001, 16.647400000000001)]
# [[]]
# [(-2.5069900000000001, 16.647400000000001)]
# [[]]

# %%
len(face_cor)

# %%
dist

# %%
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('a.avi', fourcc, 5.0, (640, 480))

# %%
import cv2
import numpy as np
import copy
cap= cv2.VideoCapture(0)
# fourcc = cv2.VideoWriter_fourcc(*'XVID')
# out = cv2.VideoWriter('b.avi', fourcc, 5.0, (640, 480))
status,pic=cap.read()
cv2.imshow('hi',pic)
cv2.waitKey()
black=(150,150,150)
while True:
    status,photo=cap.read()
    for i in range(photo.shape[0]):
        for j in range(photo.shape[1]):
            if photo[i,j,0]<black[0] and photo[i,j,1]<black[1] and photo[i,j,2]<black[2]:
                photo[i,j]=pic[i,j]
#     out.write(photo)
    cv2.imshow('hi',photo)
    if cv2.waitKey(10)==13:
        break
cv2.destroyAllWindows()
cap.release()
# out.release()

# %%
cv2.imwrite('a.jpg',photo)

# %%
cap.release()
# out.release()

# %%
cv2.imwrite('a1.jpg',pic[0])
cv2.imwrite('a2.jpg',pic[1])

# %%
gauss = cv2.GaussianBlur(photo, (7,7), 0)
# Apply Unsharp masking
unsharp_image = cv2.addWeighted(photo, 2, gauss, -1, 0)

# %%
photo.shape[0]

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(0)

# Define the codec and create VideoWriter object
#fourcc = cv2.cv.CV_FOURCC(*'DIVX')
#out = cv2.VideoWriter('output.avi',fourcc, 20.0, (640,480))
out = cv2.VideoWriter('output.avi', -1, 20.0, (640,480))

while(cap.isOpened()):
    ret, frame = cap.read()
    if ret==True:
        frame = cv2.flip(frame,0)

        # write the flipped frame
        out.write(frame)

        cv2.imshow('frame',frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

# Release everything if job is finished
cv2.destroyAllWindows()

# %%
cap.release()
out.release()

# %%
import smtplib

sender_email = "narayanhari1997@gmail.com"
rec_email = "narayanharimittal@gmail.com"
password = ''
message = "Hey, this was sent using python"

server = smtplib.SMTP('smtp.gmail.com', 587)
server.starttls()
server.login(sender_email, password)
print("Login success")
server.sendmail(sender_email, rec_email, message)
print("Email has been sent to ", rec_email)

# %%
block print any error messages to stdout:

import smtplib, ssl

smtp_server = "smtp.gmail.com"
port = 587  # For starttls
sender_email = "narayanhari1997@gmail.com"
password = ''

# Create a secure SSL context
context = ssl.create_default_context()

# Try to log in to server and send email
try:
    server = smtplib.SMTP(smtp_server,port)
    server.ehlo() # Can be omitted
    server.starttls(context=context) # Secure the connection
    server.ehlo() # Can be omitted
    server.login(sender_email, password)
    # TODO: Send email here
except Exception as e:
    # Print any error messages to stdout
    print(e)
finally:
    server.quit()

# %%
import smtplib 
  
# creates SMTP session 
s = smtplib.SMTP('smtp.gmail.com', 587) 
  
# start TLS for security 
s.starttls() 
  
# Authentication 
s.login("narayanhari1997@gmail.com", "") 
  
# message to be sent 
message = "Message_you_need_to_send"
  
# sending the mail 
s.sendmail("narayanhari1997@gmail.com", "narayanharimittal@gmail.com", message) 
  
# terminating the session 
s.quit()

# %%
cv2.imshow('hi',photo)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
cv2.imwrite('abc.jpg',photo)
